# %% [markdown]
# ## Import Required Libraries

# %%
# Import the required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read Dataset using Pandas Library
baseData = pd.read_csv(r"D:\Data Files\Kaggle Datasets\Bank Churn Dataset\ChurnModelling.csv")

# %%
# To view the first 5 lines of the dataset.
baseData.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
# To view the bottom 5 lines of the dataset.
baseData.tail()
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 9995       0.00              2          1               0         96270.64
# 9996   57369.61              1          1               1        101699.77
# 9997       0.00              1          0               1         42085.58
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# ...

# %%
# To view the shape of the data. To see how many rows and columns are there in the dataset.
baseData.shape
print("The Number of Rows in the dataset are:", data.shape[0])
print("The Number of Columns in the dataset are:", data.shape[1])
# Out:
# The Number of Rows in the dataset are: 110023
# The Number of Columns in the dataset are: 13

# %%
# To findout if any null values in the dataset.
baseData.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## Conclusion:
# 1) The Dataset has no null values.

# %%
# To view the information of the Dataset.
baseData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
# To view the data types of the dataset.
baseData.dtypes
# Out:
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
# To view if any duplicate values are existing in the dataset.
baseData.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Conclusion:
# 1) Dataset has no duplicates values.

# %%
# To view the columns of the dataset.
list(baseData.columns)
# Out:
# ['CustomerId',
#  'Surname',
#  'CreditScore',
#  'Geography',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Exited']

# %%
# We are to drop the columns whatever is not going to be used in our analysis.
baseData.drop(columns = 'RowNumber', inplace = True)

# %%
# To see the information about the dataset after dropping the columns.
baseData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
# To see the Number of customers based on the Geography.
baseData['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %% [markdown]
# ## Conclusion:
# 1) Dataset has 5014 Customers based ion France.
# 2) Dataset has 2509 Customers based ion Germany.
# 3) Dataset has 2477 Customers based ion Spain.

# %%
# We will plot a pie chart using based on the Geography columns.
plt.figure(figsize=(10,6))
plt.pie(baseData['Geography'].value_counts(), labels = ['France', 'Germany', 'Spain'], autopct='%2.2f%%', explode = [0,0,0.1])
plt.title("Distribution of Country")
plt.tight_layout()
plt.show()

# %%
# To view the columns of the dataset.
baseData.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
# To find out the number of customers based on the gender.
Gender = baseData['Gender'].value_counts().reset_index()
Gender
# Out:
#    Gender  count
# 0    Male   5457
# 1  Female   4543

# %% [markdown]
# ## Conclusion:
# 1) There are 5457 Males customers in the dataset.
# 2) There are 4543 Males customers in the dataset.

# %%
# Let us plot the data based on the gender.
sns.barplot(data=Gender, x ='Gender', y ='count')
plt.title('Weightage of Gender')
plt.ylabel('Total Count')
plt.tight_layout()
plt.show()

# %%
baseData['NumOfProducts'].sum()
# Out:
# 15302

# %%
NumofProducts=baseData.groupby('Gender')['NumOfProducts'].sum().reset_index()
NumofProducts
# Out:
#    Gender  NumOfProducts
# 0  Female           7015
# 1    Male           8287

# %% [markdown]
# ## Conclusion:
# 1) There are 7015 products being used by Female Customers.
# 2) There are 8287 products being used by Male Customers.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=baseData, x= 'Age', y='EstimatedSalary', hue='Gender')
plt.title('Plotting Age Vs. Salary')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=baseData, x= 'CreditScore', y='EstimatedSalary', hue='Gender')
plt.title('Plotting Credit Score Vs. Salary')
plt.tight_layout()
plt.show()

# %%
# To find the tenure of customers with the bank.
Tenure = baseData['Tenure'].value_counts().reset_index()
Tenure
# Out:
#     Tenure  count
# 0        2   1048
# 1        1   1035
# 2        7   1028
# 3        8   1025
# 4        5   1012
# 5        3   1009
# 6        4    989
# 7        9    984
# 8        6    967
# 9       10    490
# 10       0    413

# %% [markdown]
# ## Conclusion:
# 1) The longest term is 10 years and there are 490 customers who are stable with bank.
# 2) The shortest period is less than a year, and there are 413 customers who has left bank with in a year.

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=Tenure, x = 'Tenure', y='count')
plt.title("The Number of Years The Customer Has Been With The Bank")
plt.tight_layout()
plt.show()

# %%
baseData.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
baseData.groupby('Geography')['Gender'].size()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: Gender, dtype: int64

# %%
crosstab = pd.crosstab(baseData['Geography'], baseData['Gender'])
crosstab
# Out:
# Gender     Female  Male
# Geography
# France       2261  2753
# Germany      1193  1316
# Spain        1089  1388

# %%
# We are to drop any columns which are not be used in our analysis. 
# We will drop the customer ID as it is an automated number,# we will not use this in our analysis.
data = baseData.drop(columns='CustomerId')

# %%
# We will see the statistical measures of the dataset. 
data.describe().T.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# ...

# %%
data.sample(5)
# Out:
#         Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 1812  Trevisano          850   Germany  Female   33       7  134678.13
# 8540       Shih          484   Germany    Male   40       7  106901.42
# 2424  Chijindum          573    France    Male   31       2       0.00
# 5342     Pedder          807   Germany    Male   47       1  171937.27
# 9813  Vasilyeva          590     Spain  Female   29      10   99250.08
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 1812              1          1               0        113177.95       0
# 8540              2          0               0        118045.98       0
# 2424              2          1               1         91957.39       0
# 5342              1          1               1         65636.92       0
# 9813              1          1               1        129629.41       0

# %%
baseData.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
# We will find the number of Active Members in the dataset.
baseData['IsActiveMember'].value_counts()
# Out:
# IsActiveMember
# 1    5151
# 0    4849
# Name: count, dtype: int64

# %% [markdown]
# ## Conclusion:
# 1) There are 5151 active members and 4849 inactive members.

# %%
baseData['IsActiveMember'].value_counts().plot(kind = 'bar')
plt.title("Active Member Yes/No")
plt.tight_layout()
plt.xlabel("Count")
plt.ylabel("Total Customers")
plt.xticks(rotation=0)
plt.show()
